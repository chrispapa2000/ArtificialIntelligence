# %% [markdown]
# ## Ομάδα 57
#
# Στοιχεία Μέλους 1: Xρήστος Παπαδημητρίου, el18017

# %% [markdown]
# # Τεχνητή Νοημοσύνη: Εργαστηριακή Άσκηση 2
# ---
#
# Ο στόχος της εργασίας είναι η κατασκευή ενός συστήματος προτάσεων (Recommendation System) για ταινίες. Οι προτάσεις αυτές θα πηγάζουν τόσο από τα χαρακτηριστικά της ταινίας όσο και από ορισμένες αξιολογήσεις του κάθε χρήστη.
#
# Στα δεδομένα της άσκησης περιλαμβάνονται ένα αρχείο με το όνομα movies_metadata.csv το όποιο περιέχει τα χαρακτηριστικά κάθε ταινίας όπως θέμα, σκηνοθέτης ηθοποιοί, λέξεις κλειδιά κ.α. από το imdb καθώς και τα αρχεία ratings.csv τα όποια περιέχουν πραγματικές αξιολογήσεις χρηστών, χωρισμένες σε train και σε test.

# %% [markdown]
# # Εκφώνηση
# Στην παρούσα εργασία σας ζητείται να μελετήσετε και να υλοποιήσετε τα παρακάτω:<br>
#
# ### Μέρος 1
# Στο μέρος 1 και 2 θα εργαστείτε μόνο με το αρχείο movies_metadata.csv, ενώ στο μέρος τρία θα δουλέψετε και με τα αρχεία των αξιολογήσεων.
# #### Ερώτημα 1α
#
# Αρχικά θα πρέπει, αφού μελετήσετε τη δομή και τα χαρακτηριστικά του movies_metadata.csv, να κατασκευάσετε μια βάση γνώσης για την Prolog η όποια ουσιαστικά θα αποτελεί τον κόσμο με τον όποιο θα εργαστείτε στην συνέχεια. Τα κατηγορήματα που θα δημιουργηθούν θα σας βοηθήσουν και στην κατασκευή του recommender και θα είναι της μορφής:
#
# ```
# director(Movie, Director).
# genre(Movie, Genre).
# ```
# #### Ερώτημα 1β
#
# Αφού δημιουργήσετε τον κόσμο του προβλήματος, στη συνέχεια καλείστε να δημιουργήσετε, σε Prolog, απλούς κανόνες οι οποίοι θα βρίσκουν όλες τις ταινίες με:
# 1.	Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές)
# 2.	Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)
# 3.	Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)
# 4.	Κοινός σκηνοθέτης
# 5.	Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)
# 6.	Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)
# 7.	Ίδιους τους βασικούς ηθοποιούς (και τους 3)
# 8.	Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)
# 9.	Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)
# 10.	Ίδια γλώσσα
# 11.	Είναι έγχρωμες ή ασπρόμαυρες
# 12. Κοινό studio παραγωγής
# 13. Κοινή χώρα παραγωγής
# 14. Ίδια δεκαετία
#
# Αξίζει να σημειωθεί ότι στα παραπάνω μπορείτε να προσθέσετε περισσότερα ερωτήματα ή να αλλάξετε την κλιμακωσιμότητα των queries (πέρα από το ίδιο, αρκετά ίδιο, σχετικά ίδιο) που θα κατασκευάσετε(π.χ. μια κλίμακα από 1 στα 5 όπου αυτό είναι δυνατόν), μιας και αυτά στην συνέχεια θα χρησιμοποιηθούν για την λειτουργία του recommender. Έτσι μπορείτε να προσθέσετε queries με τα όποια μπορεί να παράγονται καλύτερες συστάσεις  (το αρχείο movie_metadata.csv περιέχει πολλές πληροφορίες ακόμα για κάθε ταινία όπως έτος κυκλοφορίας, βαθμολογία στο imdb, facebοok_likes κ.α.). Το συγκεκριμένο μέρος εργασίας είναι προπαρασκευαστικό οπότε όσο καλύτερα και πλουσιότερα τα ερωτήματα που θα φτιάξετε σε αυτό το μέρος τόσο καλύτερη θα είναι η απόδοσή των συστημάτων συστάσεων των επόμενων ερωτημάτων.
#
# Περισσότερες πληροφορίες για το dataset μπορείτε να διαβάσετε σε αυτό το [Link](https://www.kaggle.com/georgefila/movies-metadata).
# ### Μέρος 2: Recommendation System
# Στο σημείο αυτό καλείστε με βάση αυτά που κάνατε στο μέρος 1 να κατασκευάσετε queries τα όποια θα σας επιστρέφουν παρόμοιες (σε χαρακτηριστικά) ταινίες. Τα ερωτήματα αυτά θα είναι κλιμακούμενα, δηλαδή θα υπάρχουν ερωτήματα που επιστρέφουν αρκετά κοινές ταινίες αλλά και που επιστρέφουν λιγότερο και λιγότερο κοινές (σε μια κλίμακα π.χ. από 1 σε 5). Για παράδειγμα:
#
# ```
# find_simmilar_movies_5("Pirates Of The Caribbean", M).
# M = "Pirates Of The Caribbean: On Stranger Tides"
# M = "The Chronicles Of Narnia"
# M = "Prince Of Persia: The Sands Of Time"
# ...
# ```
# Για παράδειγμα, το παραπάνω ερώτημα θα επιστρέφει αρκετά κοινές σε περιεχόμενο ταινίες με την ταινια "Pirates Of The Caribbean". Θα υπάρχουν και αντίστοιχα ερωτήματα που θα βρίσκουν λιγότερο όμοιες ταινίες. Ο δείκτης ομοιότητας των ταινιών είναι αυθαίρετος και μπορείτε να τον ορίσετε εσείς όπως θέλετε, αρκεί να υπάρχει κάποια λογική σύνδεση με τα δεδομένα που περιέχονται στο αρχείο movies_metadata.csv.
#
# Συνεπώς η συνάρτηση που θα κάνει τις προτάσεις (recommendation) με είσοδο μια ταινία πρέπει να επιστρέφει-εκτυπώνει μια λίστα με τις προτεινόμενες ταινίες κατά φθίνουσα σειρά ομοιότητας.
#
#
# ### 3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις - Αξιολογήσεις του χρήστη
#
#
# Σε αυτό το σημείο θα εργαστείτε με τα αρχεία ratings τα όποια περιέχουν αξιολογήσεις (από 1 μέχρι 5) για τις παραπάνω ταινίες. Το προηγούμενο σύστημα συστάσεων προτείνει στον χρήστη ταινίες αποκλειστικά με βάση την ομοιότητά τους. Σε αυτό το σημείο θα γίνει μια αναβάθμιση του συστήματος έτσι ώστε να παράγονται καλύτερες  συστάσεις οι όποιες θα λαμβάνουν υπόψιν και τις προτιμήσεις του χρήστη, οι όποιες θα εξάγονται από τις αξιολογήσεις που έχει κάνει μέχρι στιγμής.
#
# Η εκπαίδευση του recommender θα γίνεται ως εξής:
#
# Για κάθε ταινία θα υπάρχει ένα score το όποιο αρχικά θε είναι ίσο με 0 και θα διαμορφώνεται από τις αξιολογήσεις κάθε user. Έτσι για έναν χρήστη με βάση τις αξιολογήσεις που υπάρχουν στο αρχείο train_ratings θα πρέπει:
#
# 1.	Για κάθε ταινία που έχει βαθμολογήσει να βρίσκονται οι κοινές ταινίες ανά κλίμακα και στο μέχρι τώρα σκορ κάθε παρόμοιας ταινίας θα προστίθεται ένα βάρος το όποιο θα μπορούσε να είναι το ποσοστό ομοιότητας της ταινίας (δηλαδή ένα βάρος για κάθε κλίμακα, αν δύο ταινίες μοιάζουν ενισχύουμε το βάρος που προσθέτουμε από το να μοιάζουν λιγότερο) επί τον βαθμό που έχει βάλει ο χρήστης για την αρχική ταινία (διαφορετικό είναι ο χρήστης να έχει βάλει 5/5 ή 1/5 σε μια ταινία από 3/5).
#
# 2. Στη συνέχεια, ανάλογα με το σκορ που έχει σχηματιστεί για κάθε ταινία, θα επιλέγεται αν αυτή θα μπορούσε να είναι προτεινόμενη για τον χρήστη ή όχι και θα μετράμε το πόσο καλά τα πήγε το σύστήμά μας με βάση ορισμένες μετρικές.
#
# Η λογική πίσω από την παραπάνω διαδικασία είναι ότι παρόμοιες ταινίες θα έχουν ανάλογο βαθμό. Για παράδειγμα αν ένας χρήστης έχει αξιολογήσει αρκετές  ταινίες οι όποιες είναι sci-fiction με 5/5 τότε μια ταίνια sci-fiction την όποια δεν έχει δεί λογικά θα του αρέσει και θα έπρεπε να την προτείνουμε.
#
# Μετά την εκπαίδευση του συστήματος σας καλείστε να δοκιμάσετε τον recommender που κατασκευάσατε στην πράξη. Για τον σκοπό αυτό θα φορτώσετε το αρχείο test_ratings.csv όπου περιέχονται οι αξιολογήσεις του ίδιου χρήστη για άλλες ταινίες. Το σύστημά σας πρέπει να προβλέπει αν μια ταινία θα πρέπει να προταθεί στον χρήστη. Μια ταίνια θεωρούμε οτι προτείνεται στον  χρήστη, αν έχει βαθμό μεγαλύτερο του 3 στο test_ratings. Συνεπώς για την επίβλεψη του συστήματός σας θα πρέπει για κάθε μια από τις ταινίες του αρχείου test_ratings.csv να προβλέψετε εάν θα αρέσει στο χρήστη ή όχι ώστε να την προτείνετε.
#
# ΠΡΟΣΟΧΗ! Η "βαθμολογία" που θα υπολογίσετε για κάθε ταινία κατά το training δεν είναι απαραίτητα πρόβλεψη της βαθμολογίας που θα έβαζε ο χρήστης.
#
# Στην συνέχεια, σε συνδιασμό με τις πραγματικές απαντήσεις του χρήστη θα αξιολογήσετε το σύστημά σας χρησιμοποιόντας τις μετρικές: precision, recall, f1 οι οποίες είναι οι πλέον γνωστές μετρικές και ευρέως χρησιμοποιούμενες τεχνικές για την επίβλεψη-μέτρηση απόδοσης ανάλογων συστημάτων.
#
# 1. Precision: Δείχνει πόσο ακριβές είναι το σύστημα. Υπολογίζει πόσα από τα στιγμιότυπα τα όποια προβλέψαμε ότι ανήκουν σε μια κλάση όντως ανήκουν σε αυτή. Η μετρική αυτή μας δίνει μια εικόνα σχετικά με τον αριθμό των ταινίων που προβλέψαμε ως προτεινόμενες ενώ δεν θα έπρεπε.
#
# 2. Recall: Υπολογίζει πόσα από τα στιγμιότυπα που ανήκουν σε μια κλάση (π.χ. προτεινόμενες ταινίες) προβλέφθηκαν σωστά.
#
# 3. F1: Είναι ένας μέσος μεταξύ των παραπάνω δυο μετρικών, έτσι ώστε να διατηρείται μια ισορροπία μεταξύ τους. Υπολογίζεται από την παρακάτω σχέση:
#
# $$F_1=2\frac{Precision\times{Recall}}{Precision+Recall}$$
#
# Οι παραπάνω συναρτήσεις παρέχονται από την βιβλιοθήκη scikit-learn.
#
# Τέλος για την καλύτερη επίβλεψη του συστήματος σας μπορείτε να εκπαιδεύσετε  τον recommender σας με ένα υποσύνολο ταινίων από ελάχιστες, λίγες μέχρι και πολλές (π.χ. 3, 5, 10, 50, ...) για να μελετήσετε κατά πόσο σας βοηθούν οι επιπλέον αξιολογήσεις κάθε φορά (δηλαδή κατά πόσο βελτιώνονται οι παραπάνω μετρικές στο test set).
#
# Έτσι π.χ. μπορείτε να εντοπίσετε περιπτώσεις όπως για παράδειγμα ότι με έναν recommender μπορεί να μην επιτυγχάνετε πολύ υψηλό σκορ όσο με άλλους, αλλά το βέλτιστο σκόρ σας επιτυγχάνεται πολύ γρηγόρα π.χ. με μόνο 10 ταινίες αντί 100. Έτσι για παράδειγμα αν ο αλγόριθμος τα πηγαίνει πολύ καλά για τρεις ταινίες και στη συνέχεια το σκορ βελτιώνεται ελάχιστα τότε αυτός ενδείκνυται για ένα σύστημα συστάσεων για νέους χρήστες όπου δεδομένου λίγων ταινιών ο αλγόριθμος είναι σε θέση να το να προτείνει καλές συστάσεις. Ενώ αν η καλύτερη απόδοση του αλγορίθμου σας είναι βέλτιστη με περισσότερες ταινίες π.χ. 50 τότε αυτός ο αλγόριθμος συστάσεων ενδείκνυται για παλιούς χρήστες με πολλές αξιολόγησεις.

# %% [markdown]
# ---
# ## Κατασκευή Περιβάλλοντος Εργασίας
# ---
# ### Διάβασμα Αρχείων στο Colab (Μόνο για το Colab)
# Αν η υλοποίηση γίνει στο google colab τότε μπορεί να χρησιμοποιηθεί το google drive ως file system. Για να γίνει Mount το google drive τρέχουμε τον παρακάτω κώδικα και κλικάρουμε στο link που θα μας εμφανιστεί.
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# import os
# os.listdir('/gdrive/My Drive')
# ```
# Έπειτα στην σελίδα που άνοιξε επιλέγουμε το mail μας και στο επόμενο παράθυρο που θα μας ανοίξει πατάμε Να επιτρέπεται. Στην συνέχεια αντιγράφουμε τον κωδικό που θα μας βγάλει και τον κάνουμε paste στο Input που έχει ανοίξει στο colab. Έτσι πλέον αν έχουμε ανεβάσει ένα αρχείο στο google drive μπορούμε να το βρούμε στην θέση:
#
# ```
# movies_filename = '/gdrive/My Drive/' + movies_metadata.csv
# ```
# Μπορούμε πλέον κανονικά να δουλέψουμε φτιάχνοντας φακέλους ή αρχεία και γενικότερα κάνοντας οτιδήποτε θα κάναμε αν ήμασταν τοπικά.
#
# ### Prolog μέσω Python
#
# Το πακέτο που θα χρησιμοποιηθεί για την επικοινωνία Python και Prolog είναι το pyswip (https://pypi.org/project/pyswip/). Για να δουλέψει το Pyswip  χρειάζεται να υπάρχει το Swi-Prolog το όποιο αν δουλεύουμε τοπικά πρέπει να το εγκαταστήσουμε, ακολουθώντας αντίστοιχες οδηγίες στην σελίδα του εργαλείου. Για να γίνει του Swi-Prolog η εγκατάσταση στο Google Colab πρέπει να τρέξουμε τον παρακάτω κώδικα:
#
# ```
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog/stable
# !sudo apt-get update
# !sudo apt-get install swi-prolog
# ```
# Σε κάποιο σημείο της εκτέλεσης εμφανίζεται ένα μήνυμα ότι πρέπει να πατήσουμε enter σε ένα input για να συνεχίσει η διαδικασία. Έπειτα από αυτό η εκτέλεση θα συνεχίσει χωρίς κάποιο πρόβλημα.
#
# Τέλος πρέπει να εγκαταστήσουμε το pyswip (**όπου και να δουλεύουμε**) όπως παρακάτω:
#
# ```
# !pip isntall pyswip
# ```

# %% [markdown]
# ---
# # Κώδικας για κατασκευή περιβάλλοντος εργασίας
#
# ## Μόνο για Google Colab
#
# Κώδικας για να γίνει Mount to Google Drive

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# import os
# path="" # με ευκόλο τρόπο μπορείτε να αλλάξετε το path που είναι αποθηκευμένα τα αρχεία σας

# %%
# %%capture
# #install swi-prolog
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog
# !sudo apt-get update
# !sudo apt-get install swi-prolog
# #install pyswip
# !pip install pyswip

# %% [markdown]
# # **Μέρος 1: Μελέτη των Metadata, Δημιουργία κόσμου και των βασικών queries.**

# %%
import pandas as pd
from pyswip import Prolog

# %%
# Η βιβλιοθήκη pandas είναι χρήσιμη για την εργασία με τέτοια δεδομένα
import pandas as pd 
# path = '/content/drive/MyDrive/'
path = ""
# Διάβασμα του αρχείου 'movie_metadata.csv' 
data = pd.read_csv(path + "movies_metadata.csv") 
#Στο csv υπαρχούν κελία με nan τιμές
#Στις θέσεις αυτές βάζουμε 'UNK' πράγμα που  κάνουμε με την παρακάτω συνάρτηση
data.fillna("UNK", inplace=True)
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#    Unnamed: 0     budget                                    genres  \
# 0           0  237000000  Action|Adventure|Fantasy|Science Fiction
# 1           1  300000000                  Adventure|Fantasy|Action
# 2           2  245000000                    Action|Adventure|Crime
# 3           3  250000000               Action|Crime|Drama|Thriller
# 4           4  260000000          Action|Adventure|Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                        plot_keywords  language  \
# 0  culture clash|future|space war|space colony|so...   English
# 1  ocean|drug abuse|exotic island|east india trad...   English
# 2  spy|based on novel|secret agent|sequel|mi6|bri...  Français
# 3  dc comics|crime fighter|terrorist|secret ident...   English
# 4  based on novel|mars|medallion|space travel|pri...   English
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  ...  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  ...
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615  ...
# 2  A cryptic message from Bond’s past sends him o...  107.376788  ...
# 3  Following the death of District Attorney Harve...  112.312950  ...
# 4  John Carter is a war-weary, former military ca...   43.926995  ...
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                 movie_title vote_average  num_voted_users  \
# 0                                    Avatar          7.2            11800
# 1  Pirates of the Caribbean: At World's End          6.9             4500
# 2                                   Spectre          6.3             4466
# 3                     The Dark Knight Rises          7.6             9106
# 4                               John Carter          6.1             2124
#
#   title_year                   country      director_name     actor_1_name  \
# 0     2009.0  United States of America      James Cameron      Zoe Saldana
# 1     2007.0  United States of America     Gore Verbinski    Orlando Bloom
# 2     2015.0            United Kingdom         Sam Mendes  Christoph Waltz
# 3     2012.0  United States of America  Christopher Nolan    Michael Caine
# 4     2012.0  United States of America     Andrew Stanton     Lynn Collins
#
#        actor_2_name       actor_3_name
# 0  Sigourney Weaver       Stephen Lang
# 1   Keira Knightley  Stellan Skarsgård
# 2       Léa Seydoux      Ralph Fiennes
# 3       Gary Oldman      Anne Hathaway
# 4   Samantha Morton       Willem Dafoe
#
# [5 rows x 27 columns]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'budget', 'genres', 'homepage', 'id', 'plot_keywords',
#        'language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date', 'gross',
#        'duration', 'spoken_languages', 'status', 'tagline', 'movie_title',
#        'vote_average', 'num_voted_users', 'title_year', 'country',
#        'director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name'],
#       dtype='object')

# %% [markdown]
# Παρακάτω εξάγουμε τις πληροφορίες από το movies_metadata.csv και τις αποθηκεύουμε ως κατηγορήματα της Prolog:

# %%
def clean_text(text):
  text = text.replace(u'\xa0', u'')
  text = text.replace(u"'", u'')
  return text

# %%
import json

#create World
#Ορίζουμε τον κόσμο μας
prolog = Prolog()
#Για κάθε row του πίνακα φτιάχνουμε τα κατηγορήματα που θέλουμε να αποθηκέυσουμε
#αρχικά σε μια λίστ
# α με το όνομα literals
literals = []
movie_score = {}
counter = 0
for row in data.itertuples(index=True, name='Pandas'):
  # print(f"row {counter}: ")
  counter += 1
  movie_title = clean_text(getattr(row, 'movie_title'))
  # genres
  for genre in getattr(row, 'genres').split("|"):
    literals.append("genre('"+ movie_title +"','"+ genre +"')")

  # key words
  for key_word in getattr(row, 'plot_keywords').split('|'):
    literals.append("plot_keyword('"+ movie_title +"','"+ clean_text(key_word) +"')")
   
  # director
  literals.append("director('"+ movie_title +"','"+ clean_text(getattr(row, 'director_name')) +"')")

  # actors
  literals.append("actor_1('"+ movie_title +"','"+ clean_text(getattr(row, 'actor_1_name')) +"')")
  literals.append("actor_2('"+ movie_title +"','"+ clean_text(getattr(row, 'actor_2_name')) +"')")
  literals.append("actor_3('"+ movie_title +"','"+ clean_text(getattr(row, 'actor_3_name')) +"')")

  # year
  if str(getattr(row, 'title_year')) != 'UNK':
    literals.append("year('"+ movie_title +"','"+ str(int(getattr(row, 'title_year'))) +"')")

  # production countries - parse as json string
  obj = getattr(row, 'production_countries').replace("'", "\"")
  obj = json.loads(obj)
  for item in obj:
      country = item['iso_3166_1']
      literals.append("production_country('"+ movie_title +"','"+ country +"')")
  
  # production companies - parse as json string
  obj = getattr(row, 'production_companies')
  obj = eval(obj)
  for item in obj:
      company = item['name'].replace("'", "").replace("\"", "")
      literals.append("production_company('"+ movie_title +"','"+ company +"')")

  # spoken languages - parse as json string
  obj = getattr(row, 'spoken_languages').replace("'", "\"")
  obj = json.loads(obj)
  for item in obj:
      lang = item['iso_639_1']
      literals.append("language('"+ movie_title +"','"+ lang +"')")

#Η Prolog θέλει τα κατηγορήματά της με την σειρά 
literals.sort()
for literal in literals:
  prolog.assertz(literal)

#Επίσης μπορούμε να κάνουμε consult ένα έτοιμο αρχείο στον κόσμο όπως παρακάτω
prolog.consult(path + "db.pl")

# %%
import traceback
import logging

# %% [markdown]
# Στη συνέχεια παρουσιάζω τα βοηθητικά κατηγορήματα σε prolog που κατασκεύασα. Τα κατηγορήματα έχουνε δηλωθεί στο αρχείο `db.pl` το οποίο επισυνάπτω. Ωστόσο, για ευκολία τα παραθέτω και σε κελιά Markdown.

# %% [markdown]
# #### _Comparing Genres:_

# %% [markdown]
# Αρχικά με το κατηγόρημα `find_genre_sim/3` μπορούμε να βρούμε την ομοιότητα μεταξύ δύο ταινιών (αριθμός κοινών genres).

# %% [markdown]
# Σε Prolog:
# ```prolog
# common_genre(X,Y,G):- genre(X,G), genre(Y,G), X\=Y.
#
# find_genre_sim(X,Y,L):-
#     setof(G, common_genre(X,Y,G), B),
#     list_to_set(B,S),
#     length(S,L1),
#     L is L1.
# ```

# %%
prolog.consult(path + "db.pl")
q = prolog.query("find_genre_sim('John Carter', Movie, Similarity)")
print("similarities compared to 'John Carter':")
counter = 0
try:
    answers = [item for item in q]
    counter = 0
    for soln in answers:
        print(f"{counter} : similarity with '{soln['Movie']}' is {soln['Similarity']}")
        counter+=1
        if counter == 10:
            break
    q.close()

except Exception as e:
    logging.error(traceback.format_exc())
    q.close()
# Out:
# similarities compared to 'John Carter':
# 0 : similarity with '10 Cloverfield Lane' is 1
# 1 : similarity with '10th & Wolf' is 1
# 2 : similarity with '12 Rounds' is 2
# 3 : similarity with '127 Hours' is 1
# 4 : similarity with '13 Hours: The Secret Soldiers of Benghazi' is 1
# 5 : similarity with '15 Minutes' is 1
# 6 : similarity with '16 Blocks' is 2
# 7 : similarity with '1911' is 2
# 8 : similarity with '1941' is 1
# 9 : similarity with '2 Fast 2 Furious' is 1

# %% [markdown]
# Χρησιμοποιώντας το `find_genre_sim/3` κατασκευάζουμε τα `strongly_common_subject/3`, `common_subject/3` και `weakly_common_subject/3` που δειχνουν ότι δύο ταινίες έχουν ομοιότητα 5 και πάνω, 3 και πάνω, 1 και πάνω αντίστοιχα. Ενδεικτικά παρακάτω δείχνουμε ένα παράδειγμα για το `common_subject` (ομοιότητα από 3 και πάνω).
#
# Σε Prolog:
#
# ```prolog
# strongly_common_subject(X,Y,L):-
#     find_genre_sim(X,Y,L),
#     @>=(L,4).
#
# common_subject(X,Y,L):-
#     find_genre_sim(X,Y,L),
#     @>=(L,2).
#
# weakly_common_subject(X,Y,L):-
#     find_genre_sim(X,Y,L),
#     @>=(L,1).
# ```

# %%
prolog.consult(path + "db.pl")
q = prolog.query("common_subject('Avatar', Movie, Similarity)")
counter = 0
print(f"Some movies that have a common subject with 'Avatar':")
try:
    answers = [item for item in q]
    answers.sort(key=lambda item: item['Similarity'], reverse=True)
    
    counter = 0
    for soln in answers:
        print(f"{counter}: {soln['Movie']} (similarity={soln['Similarity']})")
        if counter == 10:
            break
        counter+=1
        
    q.close()

except Exception as e:
    logging.error(traceback.format_exc())
    q.close()
# Out:
# Some movies that have a common subject with 'Avatar':
# 0: Batman (similarity=4)
# 1: Beastmaster 2: Through the Portal of Time (similarity=4)
# 2: Blade: Trinity (similarity=4)
# 3: Dragonball Evolution (similarity=4)
# 4: Final Fantasy: The Spirits Within (similarity=4)
# 5: Jimmy Neutron: Boy Genius (similarity=4)
# 6: Jupiter Ascending (similarity=4)
# 7: Man of Steel (similarity=4)
# 8: Mystery Men (similarity=4)
# 9: Race to Witch Mountain (similarity=4)
# 10: Sheena (similarity=4)

# %% [markdown]
# #### _Comparing Plots:_

# %% [markdown]
# Αρχικά με το κατηγόρημα `find_plot_sim/3` μπορούμε να βρούμε την ομοιότητα μεταξύ δύο ταινιών (αριθμός κοινών keywords).
#
# Σε Prolog:
# ```Prolog
# common_plot_keyword(X,Y,K):- plot_keyword(X,K), plot_keyword(Y,K), X\=Y.
#
# find_plot_sim(X,Y,L):-
#     setof(K, common_plot_keyword(X,Y,K), B),
#     list_to_set(B,S),
#     length(S,L1),
#     L is L1.
# ```

# %%
prolog.consult(path + "db.pl")
q = prolog.query("find_plot_sim('John Carter', Movie, Similarity)")
print("plot similarities compared to 'John Carter':")
counter = 0
try:
    answers = [item for item in q]
    answers.sort(key=lambda item:item['Similarity'], reverse=True)
    counter = 0
    for soln in answers:
        print(f"{counter} : similarity with '{soln['Movie']}' is {soln['Similarity']}")
        counter+=1
        if counter == 10:
            break
    q.close()

except Exception as e:
    logging.error(traceback.format_exc())
    q.close()
# Out:
# plot similarities compared to 'John Carter':
# 0 : similarity with 'Avatar' is 3
# 1 : similarity with 'Mission to Mars' is 3
# 2 : similarity with 'The Hitchhikers Guide to the Galaxy' is 3
# 3 : similarity with 'Abraham Lincoln: Vampire Hunter' is 2
# 4 : similarity with 'Alice Through the Looking Glass' is 2
# 5 : similarity with 'Alice in Wonderland' is 2
# 6 : similarity with 'Aliens' is 2
# 7 : similarity with 'Alien³' is 2
# 8 : similarity with 'Anna Karenina' is 2
# 9 : similarity with 'Chicken Little' is 2

# %% [markdown]
# Χρησιμοποιώντας το παραπάνω ορίζουμε τα κατηγορήματα `identical_plot/3` και `similar_plot/3` που αληθεύουν για ταινίες με τουλάχιστον 3 και τουλάχιστον 1 κοινή λέξη κλειδί, αντίστοιχα.
#
# Σε Prolog:
# ```Prolog
# identical_plot(X,Y,S):-
#     find_plot_sim(X,Y,S),
#     @>=(S,2).
#
# similar_plot(X,Y,S):-
#     find_plot_sim(X,Y,S),
#     @>=(S,1).
# ```

# %%
prolog.consult(path + "db.pl")
q = prolog.query("similar_plot('Anna Karenina', Movie, Similarity)")
print(f"Some movies that have a similar plot with 'Anna Karenina':")
try:
    answers = [item for item in q]
    answers.sort(key=lambda item: item['Similarity'], reverse=True)
    
    counter = 0
    for soln in answers:
        print(f"{counter}: {soln['Movie']} (similarity={soln['Similarity']})")
        if counter == 10:
            break
        counter+=1
        
    q.close()

except Exception as e:
    logging.error(traceback.format_exc())
    q.close()
# Out:
# Some movies that have a similar plot with 'Anna Karenina':
# 0: Dances with Wolves (similarity=2)
# 1: John Carter (similarity=2)
# 2: 12 Years a Slave (similarity=1)
# 3: 13 Hours: The Secret Soldiers of Benghazi (similarity=1)
# 4: 2046 (similarity=1)
# 5: A Christmas Carol (similarity=1)
# 6: A Dangerous Method (similarity=1)
# 7: A Home at the End of the World (similarity=1)
# 8: A Scanner Darkly (similarity=1)
# 9: A Single Man (similarity=1)
# 10: A Walk Among the Tombstones (similarity=1)

# %% [markdown]
# #### _Comparing Directors_

# %% [markdown]
# Το κατηγόρημα `common_director/2` επιτυγχάνει αν δύο ταινίες έχουν τον ίδιο σκηνοθέτη.
#
# To κατηγόρημα σε Prolog:
# ```Prolog
# common_director(X,Y):- director(X,A), director(Y,A), X\=Y.
# ```

# %%
prolog.consult(path + "db.pl")
q = prolog.query("common_director('Batman Begins', Movie)")
print(f"Some movies that were directed by the same person as 'Batman Begins':")
try:
    answers = [item for item in q]
    # answers.sort(key=lambda item: item['Similarity'], reverse=True)
    
    counter = 0
    for soln in answers:
        print(f"{counter}: {soln['Movie']}")
        if counter == 10:
            break
        counter+=1
        
    q.close()

except Exception as e:
    logging.error(traceback.format_exc())
    q.close()
# Out:
# Some movies that were directed by the same person as 'Batman Begins':
# 0: Inception
# 1: Insomnia
# 2: Interstellar
# 3: Memento
# 4: The Dark Knight Rises
# 5: The Dark Knight
# 6: The Prestige

# %% [markdown]
# #### _Comparing Actors_

# %% [markdown]
# Το κατηγόρημα `common_actor/3` μπορεί να χρησιμοποιηθεί για να βρούμε την λίστα από ταινίες που έχουν κοινό ηθοποιό / κοινούς ηθοποιούς με μία συγκεκριμένη ταινία. Μάλιστα με την δεύτερη παράμετρο του κατηγορήματος, μπορούμε να προσδιορίσουμε πόσοι ηθοποιοί θέλουμε να είναι κοινοί. Π.χ. το ερώτημα `common_actor('The Dark Knight Rises',2,S)`, θα _δέσει_ το S με την λίστα των ταινιών που έχουν δύο κοινούς ηθοποιούς με το 'The Dark Knight Rises'.
#
# Τα σχετικά κατηγορήματα σε Prolog:
#
# ```Prolog
# actor(X,A):- actor_1(X,A).
# actor(X,A):- actor_2(X,A).
# actor(X,A):- actor_3(X,A).
#
# common_actor_N(_,_,[],0):-!.
#
# common_actor_N(X,Y,[A|Tail],N):-
#     actor(X,A),
#     actor(Y,A),
#     N_new is N-1,
#     X\=Y,
#     common_actor_N(X,Y,Tail,N_new),
#     \+member(A,Tail).
#
# common_actor(X,N,S):-
#     setof(Y, common_actor_N(X,Y,_,N), S),
#     !.
# ```

# %%
prolog.consult(path + "db.pl")
q = prolog.query("common_actor('The Dark Knight Rises',1,S)")
# gen = traverse_generator(q)
print("Some movies that have at least one common actor with 'The Dark Knight Rises':")
try:
    answers = [item for item in q]
    soln = answers[0]
    s = soln['S'] 
    counter = 0
    for item in s:
        print(f"{counter} : {item}")
        counter+=1
    q.close()

except Exception as e:
    logging.error(traceback.format_exc())
    q.close()
# Out:
# Some movies that have at least one common actor with 'The Dark Knight Rises':
# 0 : Alice Through the Looking Glass
# 1 : Alice in Wonderland
# 2 : Get Smart
# 3 : Interstellar
# 4 : Les Misérables
# 5 : Love & Other Drugs
# 6 : Rio
# 7 : Rio 2
# 8 : The Devil Wears Prada
# 9 : The Intern
# 10 : The Other Side of Heaven

# %% [markdown]
# #### _Comparing Languages_

# %% [markdown]
# Το κατηγόρημα `common_language/3` μπορεί να χρησιμοποιηθεί για να βρούμε την λίστα από ταινίες που έχουν κάποια γλώσσα / κάποιες γλώσσες κοινές με μία συγκεκριμένη ταινία. Μάλιστα με την δεύτερη παράμετρο του κατηγορήματος, μπορούμε να προσδιορίσουμε πόσες γλώσσες θέλουμε να είναι κοινές. Π.χ. το ερώτημα `common_actor('Rio',2,S)`, θα _δέσει_ το S με την λίστα των ταινιών που έχουν δύο κοινές γλώσσες με το 'Rio'.
#
# Τα σχετικά κατηγορήματα σε Prolog
# ```Prolog
# common_language_N(_,_,[],0):-!.
#
# common_language_N(X,Y,[A|Tail],N):-
#     language(X,A),
#     language(Y,A),
#     N_new is N-1,
#     X\=Y,
#     common_language_N(X,Y,Tail,N_new),
#     \+member(A,Tail).
#
# common_language(X,N,S):-
#     setof(Y,common_language_N(X,Y,_,N), S),
#     !.
# ```

# %%
import traceback
import logging

prolog.consult(path + "db.pl")
q = prolog.query("common_language('Rio',2,S)")

print("Some movies that have at least two common languages with 'Rio':")
try:
    answers = [item for item in q]
    soln = answers[0]
    s = soln['S'] 
    counter = 0
    for item in s:
        print(f"{counter} : {item}")
        counter+=1
    q.close()

except Exception as e:
    logging.error(traceback.format_exc())
    q.close()
# Out:
# Some movies that have at least two common languages with 'Rio':
# 0 : 13 Going on 30
# 1 : 2012
# 2 : 90 Minutes in Heaven
# 3 : Alive
# 4 : Alone in the Dark
# 5 : Area 51
# 6 : BloodRayne
# 7 : Christmas Eve
# 8 : Cleopatra
# 9 : Click
# 10 : Cry_Wolf
# 11 : Deuce Bigalow: European Gigolo
# 12 : Eat Pray Love
# 13 : Fast Five
# 14 : Fever Pitch
# 15 : Fight Valley
# 16 : Flashdance
# 17 : Friday After Next
# 18 : Garfield: A Tail of Two Kitties
# 19 : Grandmas Boy
# 20 : Griff the Invisible
# 21 : Guess Who
# 22 : Held Up
# 23 : Howard the Duck
# 24 : Lets Go to Prison
# 25 : Love Actually
# 26 : Love Stinks
# 27 : Madagascar
# 28 : Master and Commander: The Far Side of the World
# 29 : Monster-in-Law
# 30 : One Direction: This Is Us
# 31 : Open Road
# 32 : Priest
# 33 : Rio 2
# 34 : Road House
# 35 : Safe Haven
# 36 : Saving Silverman
# 37 : Shark Night
# 38 : Signs
# 39 : Sinister
# 40 : Sleepover
# 41 : Speed 2: Cruise Control
# 42 : Stigmata
# 43 : The Incredible Hulk
# 44 : The Interpreter
# 45 : The Invention of Lying
# 46 : The Kite Runner
# 47 : The Last Sin Eater
# 48 : The Life Aquatic with Steve Zissou
# 49 : The Nativity Story
# 50 : The New Guy
# 51 : The Ninth Gate
# 52 : The Rundown
# 53 : Thirteen
# 54 : Trading Places
# 55 : Trash
# 56 : Woman on Top

# %% [markdown]
# #### _Black and White_

# %% [markdown]
# Το κατηγόρημα `black_and_white/1` επιτυγχάνει όταν μία ταινία είναι ασπρόμαυρη ή διαθέτει κάποιες ασπρόμαυρες σκηνές. Τα σχετικά κατηγορήματα σε Prolog:
#
# ```Prolog
# find_black_and_white(M):-
#     plot_keyword(M,'black and white').
#
# find_black_and_white(M):-
#     plot_keyword(M,'black and white scene').
#
# black_and_white(S):-
#     setof(M,find_black_and_white(M),S),
#     !.
# ```

# %%
import traceback
import logging

prolog.consult(path + "db.pl")
q = prolog.query("black_and_white(S)")

print("Movies that are black and white or contain black and white scenes:")
try:
    answers = [item for item in q]
    answers = answers[0]['S']
    counter = 0
    for item in answers:
        print(f"{counter} : {item}")
        counter+=1
    q.close()

except Exception as e:
    logging.error(traceback.format_exc())
    q.close()
# Out:
# Movies that are black and white or contain black and white scenes:
# 0 : Creative Control
# 1 : Frances Ha
# 2 : Frankenweenie
# 3 : Oceans Eleven
# 4 : Renaissance
# 5 : Sin City
# 6 : The Giver
# 7 : The Phantom of the Opera

# %% [markdown]
# #### _Common Production Company_

# %% [markdown]
# To κατηγόρημα `common_company/2` δένει την δεύτερη παράμετρό του με το σύνολο των ταινιών που έχουν κάποια κοινή εταιρεία παραγωγής με την ταινία στόχο (πρώτη παράμετρο). Τα σχετικά κατηγορήματα σε Prolog:
#
# ```Prolog
# find_common_company(X,Y,C):-
#     production_company(X,C),
#     production_company(Y,C),
#     X\=Y.
#
# common_company(X,S):-
#     setof(Y, find_common_company(X,Y,_), S),
#     !.
# ```

# %%
import traceback
import logging

prolog.consult(path + "db.pl")
q = prolog.query("common_company('The Dark Knight Rises',S)")

print("Some movies that have at least one common production company with 'The Dark Knight Rises':")
try:
    answers = [item for item in q]
    soln = answers[0]
    s = soln['S'] 
    counter = 0
    for item in s:
        print(f"{counter} : {item}")
        counter+=1
    q.close()

except Exception as e:
    logging.error(traceback.format_exc())
    q.close()
# Out:
# Some movies that have at least one common production company with 'The Dark Knight Rises':
# 0 : Batman Begins
# 1 : Batman v Superman: Dawn of Justice
# 2 : Batman: The Dark Knight Returns, Part 2
# 3 : Green Lantern
# 4 : Man of Steel
# 5 : RED
# 6 : RED 2
# 7 : Steel
# 8 : Suicide Squad
# 9 : The Dark Knight
# 10 : The Losers

# %% [markdown]
# #### _Common Production Country_
#
# To κατηγόρημα `common_country/2` δένει την δεύτερη παράμετρό του με το σύνολο των ταινιών που έχουν κάποια κοινή χώρα παραγωγής με την ταινία στόχο (πρώτη παράμετρο). Τα σχετικά κατηγορήματα σε Prolog:
#
# ```Prolog
# common_country_N(_,_,[],0):-!.
#
# common_country_N(X,Y,[A|Tail],N):-
#     production_country(X,A),
#     production_country(Y,A),
#     X\=Y,
#     N_new is N-1,
#     common_country_N(X,Y,Tail,N_new),
#     \+member(A,Tail).
#
# common_country(X,N,S):-
#     setof(Y, common_country_N(X,Y,_,N), S),
#     !.
# ```

# %%
import traceback
import logging

prolog.consult(path + "db.pl")
q = prolog.query("common_country('Alien',2,S)")

print("Some movies that have at least two common production countries with 'Alien':")
try:
    answers = [item for item in q]
    soln = answers[0]
    s = soln['S'] 
    counter = 0
    for item in s:
        print(f"{counter} : {item}")
        counter+=1
    q.close()

except Exception as e:
    logging.error(traceback.format_exc())
    q.close()
# Out:
# Some movies that have at least two common production countries with 'Alien':
# 0 : 12 Years a Slave
# 1 : 127 Hours
# 2 : 2001: A Space Odyssey
# 3 : 40 Days and 40 Nights
# 4 : 8 Heads in a Duffel Bag
# 5 : A Bridge Too Far
# 6 : A Funny Thing Happened on the Way to the Forum
# 7 : A Mighty Heart
# 8 : A Most Wanted Man
# 9 : A Passage to India
# 10 : A Serious Man
# 11 : A Sound of Thunder
# 12 : A View to a Kill
# 13 : AVP: Alien vs. Predator
# 14 : About a Boy
# 15 : Alexander
# 16 : Alfie
# 17 : Alice Through the Looking Glass
# 18 : Aliens
# 19 : Alien³
# 20 : All Hat
# 21 : American Gangster
# 22 : An American Haunting
# 23 : An Education
# 24 : An Ideal Husband
# 25 : Around the World in 80 Days
# 26 : Atonement
# 27 : Australia
# 28 : Avatar
# 29 : Barry Lyndon
# 30 : Basic Instinct 2
# 31 : Batman
# 32 : Batman & Robin
# 33 : Batman Begins
# 34 : Batman Forever
# 35 : Batman Returns
# 36 : Be Kind Rewind
# 37 : Becoming Jane
# 38 : Bend It Like Beckham
# 39 : Beyond the Sea
# 40 : Big Miracle
# 41 : Birth
# 42 : Birthday Girl
# 43 : Black Hawk Down
# 44 : Black Mass
# 45 : Blade Runner
# 46 : Blood and Chocolate
# 47 : Blood and Wine
# 48 : Body of Lies
# 49 : Born to Fly: Elizabeth Streb vs. Gravity
# 50 : Bride & Prejudice
# 51 : Bridget Jones: The Edge of Reason
# 52 : Bridget Joness Diary
#     atom_number(A,N),
#     atom_number(B,M),
#     C is abs(N-M),
#     =<(C,10).
#
# find_same_decade(X,Y,A,B):-
#     year(X,A),
#     year(Y,B),
#     diff_under_10(A,B).
#
# same_dacade(X,S):-
#     setof(Y, find_same_decade(X,Y,_,_), S),
#     !.
# ```

# %%
prolog.consult(path + "db.pl")
q = prolog.query("same_dacade('Alien',S)")

print("Some movies that were produced in the same decade as 'Alien':")
try:
    answers = [item for item in q]
    soln = answers[0]
    s = soln['S'] 
    counter = 0
    for item in s:
        print(f"{counter} : {item}")
        counter+=1
    q.close()

except Exception as e:
    logging.error(traceback.format_exc())
    q.close()
# Out:
# Some movies that were produced in the same decade as 'Alien':
# 0 : Butch Cassidy and the Sundance Kid
# 1 : Machine Gun McCain
# 2 : Midnight Cowboy
# 3 : Mississippi Mermaid
# 4 : On Her Majestys Secret Service
# 5 : Paint Your Wagon
# 6 : Sweet Charity
# 7 : The Stewardesses
# 8 : The Wild Bunch
# 9 : Topaz

# %%
# prolog.assertz('(directed_by(X,Y) :- findall(M,director(M,X),Y))')

# %% [markdown]
# # **2ο Μέρος: Recommendation System με βάση μόνο τα χαρακτηριστικά των ταινιών.**
#
# Στο σημείο αυτό με βάση τους κανόνες που κατασκευάστηκαν στο Μέρος 1 θα κατασκευαστούν κατηγορήματα για την ομοιότητα ταινιών. Παρακάτω δίνεται ένα μικρό παράδειγμα ενός κανόνα και πώς αυτός θα μπορούσε να γραφτεί μέσω του Pyswip. Επίσης όπως αναφέρεται και σε σχόλιο παραπάνω θα μπορεί να γραφτεί και μια βάση δεδομένων με τους κανόνες και να γίνει απευθείας consult.
#
# Στο παρακάτω παράδειγμα το 5 και το 4 εκφράζουν την ομοιότητα των ταινιών π.χ. οι ταινίες που παράγονται μέσω του find_similar_5 είναι πιο όμοιες από αυτές που παράγονται μέσω του find_similar_4.

# %%
# def simple_recommender(movie):
#     s = set()
#     q = prolog.query("find_sim_1('" + movie +"',M)")
#     for soln in q:
#         m = soln['M'] 
#         if m not in s:
#             s.add(soln['M'])
#     q.close()
#     answers = s
#     return answers

# %% [markdown]
# Τα κατηγορήματα Prolog που χρησιμοποιούνται στον `my_simple_recommender` είναι και πάλι δηλωμένα στο αρχείο `db.pl`. Τα παραθέτουμε ωστόσο και στο παρακάτω κελί Markdown. Οι κανόνες που επιλέξαμε προκέκυψαν κατά βάση πειραματικά, προσπαθώντας να πετύχουμε τον περιορισμό των συστάσεων καθώς το similarity αυξάνεται από 1 εως 5. Κατά τον πειραματισμό με διάφορους κανόνες παρατήρησα ότι είναι αρκετά δύσκολο να επιτευχθεί μία βαθμιαία/γραμμική εξέλιξη του αριθμού των συστάσεων ανάλογα με το similarity. Αυτό οφείλεται σε μεγάλο βαθμό στην φύση του Dataset. Συγκεκριμένα, τα περισσότερα χαρακτηριστηκά είτε είναι κοινά σε πάρα πολλές ταινίες έιτε σε πολύ λίγες. Ως αποτέλεσμα η συμπερίληψη πολύ συνηθισμένων χαρακτηριστηκών περιορίζει ελάχιστα των αριθμό των προτεινόμενων ταινιών, ενώ η συμπερίληψη των σπάνιων χαρακτηριστηκών στους κανόνες δημιουργεί απότομα κατόφλια ομοιότητας. Τελικά κατέληξα σε μία συλλογή κανόνων, οπού τα πρώτα δύο επίπεδα ομοιότητας είναι αρκετά ελαστικά, ενώ τα επόμενα τρία γίνονται σημαντικά πιο στενά.
#
# O recommender που έφτιαξα (`my_simple_recommeder`), χρησιμοποιεί τους κανόνες για να βρει ταινίες με ομοιότητα 1 εως 5 με την ταινία στόχο και στην συνέχεια τις επιστρέφει με φθίνουσα σειρά ομοιότητας. Συγκεκριμένα επιστέφει μια λίστα, η οποία περιέχει πρώτα τις ταινίες με ομοιότητα 5, μετά τις ταινίες με ομοιότητα 4, μετά αυτές με ομοιότητα 3 κοκ.

# %% [markdown]
# ```prolog
# find_sim_1(X,Y):-
#     weakly_common_subject(X,Y,_),
#     find_same_decade(X,Y,_,_).
#
# find_sim_2(X,Y):-
#     common_subject(X,Y,_),
#     similar_plot(X,Y,_).
#
# find_sim_3(X,Y):-
#     common_subject(X,Y,_),
#     similar_plot(X,Y,_),
#     common_country_N(X,Y,_,1),
#     find_same_decade(X,Y,_,_).
#
# find_sim_4(X,Y):-
#     common_actor_N(X,Y,_,1).
#
# find_sim_5(X,Y):-
#     common_country_N(X,Y,_,1),
#     common_language_N(X,Y,_,1),
#     common_actor_N(X,Y,_,2).
#
# find_sim_5(X,Y):-
#     common_country_N(X,Y,_,1),
#     common_language_N(X,Y,_,1),
#     common_director(X,Y).
# ```

# %%
prolog.consult(path + "db.pl")

def my_simple_recommender(movie):
    res = list()
    try:
        for sim in range(5,0,-1):
            counter = 0
            q = prolog.query(f"find_sim_{sim}('{movie}', Movie)")
            for soln in q:
                counter+=1
                m = soln['Movie']
                if m not in res:
                    res.append(m)
            # print(counter)
            q.close()
        return res
    except Exception as e:
        logging.error(traceback.format_exc())
        q.close()

# %%
res = my_simple_recommender('The Dark Knight')
print(len(res))
# Out:
# 2613

# %% [markdown]
# # **3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις-Αξιολογήσεις του χρήστη-Εκπαίδευση και Πρόβλεψη**
#
#
# Αρχικά μελετάμε τις αξιολογήσεις κάθε χρήστη για να καταλάβουμε την δομή και τις πληροφορίες κάθε αρχείου.

# %%
from tqdm import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import random

rating_weights = {0: -1, 1: -0.5, 2:0, 3:0, 4:0.5, 5:1}
score_weights = {i:i + 1 for i in range(6)} # ανάλογα με τα επίπεδα ομοιότητας που έχουν οριστεί στην simple_recommender

def train_recommender(ratings, rating_weights, score_weights, number_of_movies = 10):
    """
    Στην συνάρτηση αυτή μπορούμε να ορίζουμε ποιο υποσύνολο των αξιολογήσεων θα χρησιμοποιήσουμε για το train μαζί με τα βάρη ομοιότητας και σκορ
    Σε συνδυασμό με τον αριθμό των ταινιών που θέλουμε να χρησιμοποιήσουμε σαν σύνολο δεδομένων π.χ. 10 από τις 100 ή 3 από τις 100 κ.ο.κ
    Αν θέλουμε να χρησιμοποιήσουμε όλες τις ταινίες σαν training set τότε ορίζουμε το number_of_movies = - 1
    """

    if number_of_movies > len(ratings):
        number_of_movies = len(ratings)


    if number_of_movies != -1:
        indexes = random.sample(range(len(ratings)), number_of_movies)
        ratings = ratings.iloc[indexes]

    movie_score = {}
    for row in tqdm(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        similar_movies = my_simple_recommender(movie)

        for similar_movie in similar_movies:
            if similar_movie not in movie_score:
                movie_score[similar_movie] = rating_weights[int(rating)] * score_weights[int(rating)]
            else:
                movie_score[similar_movie] += rating_weights[int(rating)] * score_weights[int(rating)] # το weight θα το ορίσετε ανα επίπεδο ομοιότητας οι πολύ όμοιες ταινίες θα έχουν μεγαλύτερο βάρος
    return movie_score


# Αυτό είναι ένα παράδειγμα για το πως θα μπορούσε να υλοποιήθει η predict.
# Έχουμε ορίσει ότι μια ταινία θα έπρεπε να είναι προτεινόμενη αν είχε σκορ > 0.
def predict_example(ratings, movie_score):
    real, pred = [], []
    for i, row in enumerate(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        if movie in movie_score: #αν έχουμε σχηματίσει βαθμολογία για την ταινία αυτή
            pred.append(int(movie_score[movie] > 0)) #heuristic για το αν μια ταινία είναι προτεινόμενη
            real.append(int(rating > 3))# έτσι ορίζουμε ότι μια ταινία θα έπρεπε να είναι προτεινόμενη
            #η συνθήκη αυτή δεν μπορεί να αλλάξει
        else: #δεν μπορούμε να προτείνουμε κάτι για το όποιο δεν έχουμε σχηματίσει εικόνα
            pred.append(0)
            real.append(int(rating > 3))

    return real, pred


def get_metrics(real, pred):
    metrics = {}
    metrics["precision"] = precision_score(real, pred)
    metrics["recall"] = recall_score(real, pred)
    metrics["f1"] = f1_score(real, pred)
    return metrics

# %% [markdown]
# Η παραπάνω εκπαιδεύουν, τεστάρουν και μετρούν την απόδοσή του συστήματος στάσεων μας. Για την εκπαίδευση του συστήματος μπορούμε κάθε φορά να χρησιμοποιήσουμε ένα τυχαίο υποσύνολο του training set. Όμως είναι πιθανό το υποσύνολο των ταινιών αυτόν να επηρεάζει τα αποτελέσματα στο training set. Για παράδειγμα από 3 ταινίες στις 10 μπορούν για ένα πείραμα τα αποτελέσματα μας αν είναι ίδια και αυτό να μην οφείλεται στο γεγονός ότι ο ταξινομητής μας τα πηγαίνει καλά στις 3 ταινίες αλλά στο γεγονός ότι οι υπόλοιπες 7 είναι τέτοιες ταινίες που δεν μας βοηθούν καθόλου και αν είχαμε επιλέξει διαφορετικές 3 ταινίες να τα πηγαίναμε χάλια. Οπότε προτείνουμε να τρέξετε κάθε φορά έναν αριθμό πειραμάτων για κάθε υποσύνολο ταινιών π.χ. 10 πειράματα με 3 ταινίες, 10 πειράματα για 20 ταινίες κ.ο.κ. και να κρατήσετε σαν τελικό σκορ το μέσο όρο όλων των πειραμάτων. Έτσι τα αποτελέσματα των αγγλικών σας θα είναι πιο αντικειμενικά.

# %%
train_ratings = pd.read_csv(path + "train_ratings.csv")
test_ratings = pd.read_csv(path + "test_ratings.csv")

# %%
# metrics = []
# for i in range (10):
#     movie_score = train_recommender(train_ratings, rating_weights, score_weights, 10)
#     real, pred = predict_example(test_ratings, movie_score)
#     metrics.append(get_metrics(real, pred))

# for metric in metrics[0].keys():
#     print (f"{metric}: {np.mean([m[metric] for m in metrics])}")

# %% [markdown]
# #### Πειράματα
#
# Παρακάτω τεστάρουμε τον recommender μας για 10, 30, 50, 70, 90 και 100 ταινίες (υπολογίζουμε τον μέσο όρο από 10 πειράματα σε κάθε περίπτωση). Για την επιτάχυνση της διαδικασίας χρησιμοποιώ παραλληλισμό μέσω του `multiprocessing` module της python.

# %%
def calc_metrics(q, train_ratings, rating_weights, score_weights, number_of_movies):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, number_of_movies)
    real, pred = predict_example(test_ratings, movie_score)
    q.put(get_metrics(real, pred))

# %%
results = dict()
results['precision'] = dict()
results['recall'] = dict()
results['f1'] = dict()

# %%
from multiprocessing import Process, Queue

metrics = []
q = Queue()

processes = [Process(target=calc_metrics, args=(q,train_ratings, rating_weights, score_weights, 10)) for i in range(10)]

for i in range(10):
    processes[i].start()

for i in range(10):
    processes[i].join()
    
while not q.empty():
    item = q.get()
    # print(item)
    metrics.append(item)

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
    results[metric][10] = np.mean([m[metric] for m in metrics])
# Out:
# 10it [00:01,  5.16it/s]
# 10it [00:02,  4.24it/s]
# 10it [00:02,  4.17it/s]
# 10it [00:02,  3.99it/s]
# 10it [00:02,  3.57it/s]
# 10it [00:02,  3.41it/s]
# 10it [00:02,  3.43it/s]
# 10it [00:02,  3.37it/s]
# 10it [00:03,  3.24it/s]
# 10it [00:03,  3.03it/s]
# precision: 0.5147541513366956
# recall: 0.725
# f1: 0.5904174869243137

# %%
from multiprocessing import Process, Queue

metrics = []
q = Queue()

processes = [Process(target=calc_metrics, args=(q,train_ratings, rating_weights, score_weights, 30)) for i in range(10)]

for i in range(10):
    processes[i].start()

for i in range(10):
    processes[i].join()
    
while not q.empty():
    item = q.get()
    # print(item)
    metrics.append(item)

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
    results[metric][30] = np.mean([m[metric] for m in metrics])
# Out:
# 30it [00:06,  4.78it/s]
# 30it [00:07,  4.23it/s]
# 30it [00:07,  3.88it/s]
# 30it [00:07,  3.93it/s]
# 30it [00:07,  3.79it/s]
# 30it [00:08,  3.71it/s]
# 30it [00:08,  3.66it/s]
# 30it [00:08,  3.40it/s]
# 30it [00:08,  3.35it/s]
# 30it [00:08,  3.38it/s]
# precision: 0.5097424963853442
# recall: 0.9027777777777779
# f1: 0.651490151224893

# %%
from multiprocessing import Process, Queue

metrics = []
q = Queue()

processes = [Process(target=calc_metrics, args=(q,train_ratings, rating_weights, score_weights, 50)) for i in range(10)]

for i in range(10):
    processes[i].start()

for i in range(10):
    processes[i].join()
    
while not q.empty():
    item = q.get()
    # print(item)
    metrics.append(item)

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
    results[metric][50] = np.mean([m[metric] for m in metrics])
# Out:
# 50it [00:12,  4.01it/s]
# 50it [00:13,  3.84it/s]
# 50it [00:13,  3.74it/s]
# 50it [00:13,  3.63it/s]
# 50it [00:13,  3.66it/s]
# 50it [00:13,  3.64it/s]
# 50it [00:13,  3.58it/s]
# 50it [00:14,  3.46it/s]
# 50it [00:14,  3.37it/s]
# 50it [00:15,  3.30it/s]
# precision: 0.5102382327691314
# recall: 0.9319444444444445
# f1: 0.6594007744307138

# %%
from multiprocessing import Process, Queue

metrics = []
q = Queue()

processes = [Process(target=calc_metrics, args=(q,train_ratings, rating_weights, score_weights, 70)) for i in range(10)]

for i in range(10):
    processes[i].start()

for i in range(10):
    processes[i].join()
    
while not q.empty():
    item = q.get()
    # print(item)
    metrics.append(item)

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
    results[metric][70] = np.mean([m[metric] for m in metrics])
# Out:
# 70it [00:16,  4.19it/s]
# 70it [00:16,  4.15it/s]
# 70it [00:17,  4.09it/s]
# 70it [00:17,  4.03it/s]
# 70it [00:18,  3.86it/s]
# 67it [00:18,  4.31it/s]
# 70it [00:18,  3.83it/s]
# 70it [00:18,  3.76it/s]
# 70it [00:18,  3.72it/s]
# 70it [00:19,  3.68it/s]
# precision: 0.5059509455760633
# recall: 0.9472222222222223
# f1: 0.6595434918789758

# %%
from multiprocessing import Process, Queue

metrics = []
q = Queue()

processes = [Process(target=calc_metrics, args=(q,train_ratings, rating_weights, score_weights, 90)) for i in range(10)]

for i in range(10):
    processes[i].start()

for i in range(10):
    processes[i].join()
    
while not q.empty():
    item = q.get()
    # print(item)
    metrics.append(item)

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
    results[metric][90] = np.mean([m[metric] for m in metrics])
# Out:
# 90it [00:21,  4.12it/s]
# 90it [00:21,  4.10it/s]
# 90it [00:22,  4.04it/s]
# 90it [00:22,  4.02it/s]
# 90it [00:22,  4.00it/s]
# 90it [00:22,  3.99it/s]
# 90it [00:22,  3.94it/s]
# 90it [00:23,  3.86it/s]
# 90it [00:23,  3.81it/s]
# 90it [00:23,  3.79it/s]
# precision: 0.5072676119003615
# recall: 0.9694444444444443
# f1: 0.6660271745798062

# %%
from multiprocessing import Process, Queue

metrics = []
q = Queue()

processes = [Process(target=calc_metrics, args=(q,train_ratings, rating_weights, score_weights, 100)) for i in range(10)]

for i in range(10):
    processes[i].start()

for i in range(10):
    processes[i].join()
    
while not q.empty():
    item = q.get()
    # print(item)
    metrics.append(item)

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
    results[metric][100] = np.mean([m[metric] for m in metrics])
# Out:
# 100it [00:26,  3.72it/s]
# 100it [00:27,  3.69it/s]
# 100it [00:27,  3.68it/s]
# 100it [00:27,  3.66it/s]
# 100it [00:27,  3.67it/s]
# 100it [00:27,  3.66it/s]
# 100it [00:27,  3.64it/s]
# 100it [00:27,  3.63it/s]
# 100it [00:28,  3.57it/s]
# 100it [00:28,  3.56it/s]
# precision: 0.5072463768115941
# recall: 0.9722222222222221
# f1: 0.6666666666666667

# %% [markdown]
# Παρακάτω παρουσιάζω τα αποτελέσματα με μορφή διαγράμματος.

# %%
import matplotlib.pyplot as plt 

x_axis = list(results['precision'].keys())
precisions = [(results['precision'][item])*100 for item in x_axis]
recalls = [results['recall'][item]*100 for item in x_axis]
f1_scores = [results['f1'][item]*100 for item in x_axis]

plt.figure(figsize=(15,5))
plt.plot(x_axis, precisions, label='precision', color='blue')
plt.plot(x_axis, recalls, label='recall', color='red')
plt.plot(x_axis, f1_scores, label='f1 score', color='orange')
plt.title("Metrics vs Number of Movies Considered")
plt.xlabel("Number of movies considered")
plt.ylabel("% (Metric)")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# - Αρχικά, όσον αφορά των Precision, έχουμε σχεδόν σταθερή τιμή (γύρω στο 50%) ανεξάρτητα από των αριθμό των ταινιών που λαμβάνουμε υπόψιν. Αυτό σημαίνει ότι μία στις 2 ταινίες που προτείνουμε αρέσει πράγματι στον χρήστη. Συγκρίνοντας με πραγματικά συστήματα (τύπου Netflix) που κατά κοινή ομολογία είναι πολύ λιγότερο επιτυχημένα, αυτό το ποσοστό μπορεί να θεωρηθεί αρκετά καλό.
#
# - Όσον αφορά το recall, καθώς αυξάνουμε τις ταινίες που λαμβάνουμε υπόψιν, αυτό αυξάνεται. Η αύξηση είναι πολύ πιο έντονη μέχρι τις 30 ταινίες, ενώ από εκεί και πέρα ο ρυθμός της πέφτει σημαντικά.
#
# - Το f1 score, όπως είναι αναμενόμενο ανεβαίνει και αυτό, δεδομένου ότι το precision μένει πρακτικά σταθερό και το recall αυξάνεται.
#
# Με βάση τις παραπάνω παρατηρήσεις μπορούμε να πούμε ότι ο recommender είναι καλύτερος για περιπτώσεις που έχουμε στην διάθεσή μας αρκετές συστάσεις (30 και πάνω). Ωστόσο αξίζει να παρατηρήσουμε ότι ακόμα και στις περιπτώσεις που λαμβάνουμε υπόψιν λίγες ταινίες, δίνει αξιοπρεπέστατα αποτελέσματα, ειδικά αν τον συγκρίνουμε με recommenders που συναντάμε στην καθημερινότητα μας, όπως αναφέραμε πιο πριν. Συνεπώς μπορεί να θεωρηθεί αρκετά καλή λύση ακόμα και για περιπτώσεις που ποικίλει ο ποσότητα την πληροφορίας που έχουμε αν χρήστη.
